# %% [markdown]
# Pandas is a python library that enables easy exploration of structured data. This notebook will explore a dataset with pandas and introduce some common operations.
#
# For each function below, there are many options available and pandas has excellent documentation.
#
# For documentation in the notebook, type: pd.read_csv?
# For source code, type: pd.read_csv??

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# ## Read data
#
# pandas has functions to read data from a variety of sources - CSV files, excel spreadsheets, a sql database, json files etc. The central two data structures are:
#
# pd.DataFrame (multiple columns) - think tables
#
# pd.Series (single column ordered by an index) - think time-series

# %% [markdown]
# #### Question: Read data from CSV file into a dataframe. Bonus points: Read ~10% of the rows (hint: see argument skiprows)

# %%
p = 0.10

#read full dataset
df = pd.read_csv('data/training.csv') 

#read ~10% of dataset
df = pd.read_csv('data/training.csv', skiprows = lambda x: x > 0 and np.random.random()>p)

# %%
df
# Out:
#        EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0       100018      -999.000                       85.186        68.827
# 1       100022        87.075                       38.217        67.041
# 2       100027       111.271                       27.180        70.642
# 3       100044        84.860                       33.706        67.847
# 4       100045        27.788                       68.032        23.530
# 5       100046       201.473                       23.002       104.041
# 6       100112       287.995                       72.230       229.336
# 7       100117       230.352                       85.934       164.075
# 8       100118       118.996                        2.342        72.142
# 9       100124        96.998                       30.697        78.583
# 10      100132      -999.000                       69.946       110.636
# 11      100140      -999.000                       64.998        58.011
# 12      100141       122.656                       74.726        72.667
# 13      100143        71.772                       48.878        60.579
# 14      100151        81.279                       29.474        56.067
# 15      100167       145.804                       25.979        99.359
# 16      100169        89.822                       34.534        68.319
# 17      100170       143.252                       96.966        75.581
# 18      100176       109.797                       64.871        85.842
# 19      100182       142.674                       18.260        90.533
# 20      100192       102.362                       12.116        78.300
# 21      100195        35.070                       83.831        30.425
# 22      100197        74.435                       19.885        54.468
# 23      100212        85.717                       11.876        48.904
# 24      100215        82.104                        1.941        51.854
# 25      100220       121.570                       10.660        89.980
# 26      100241        62.609                       58.135        51.716
# 27      100242        55.575                       60.551        46.192
# 28      100249        91.255                       34.474        69.843
# 29      100264       112.619                       43.113        75.069
# ...        ...           ...                          ...           ...
# 25037   349648        74.230                       56.709        54.203
# 25038   349679       247.035                      128.548       167.558
# 25039   349686      -999.000                       60.835        43.943
# 25040   349688       108.901                       33.109        79.828
# 25041   349694        97.939                       63.641        69.067
# 25042   349695      -999.000                       72.851        44.818
# 25043   349696       131.691                       36.772       108.815
# 25044   349709        89.935                       42.076        71.912
# 25045   349732        82.211                        8.423        57.156
# 25046   349734       117.716                       33.683        78.513
# 25047   349745       107.954                       41.162        84.064
# 25048   349746       111.535                       78.870        77.474
# 25049   349756       124.007                       36.099        94.316
# 25050   349766       113.006                       75.650        84.994
# 25051   349769      -999.000                       73.772        58.642
# 25052   349782       123.542                       50.658        96.884
# 25053   349787       160.104                       42.899       116.011
# 25054   349791        93.271                       38.997        64.771
# 25055   349815       166.352                       96.228        94.891
# 25056   349859      -999.000                       79.097        49.857
# 25057   349861       133.285                       14.294        59.763
# 25058   349867       105.515                       24.051        80.577
# 25059   349868        84.917                        6.755        60.607
# 25060   349876       107.016                       24.519        62.077
# 25061   349922       292.290                       76.294       101.434
# 25062   349937      -999.000                       42.555        93.236
# 25063   349966      -999.000                       83.871        17.081
# 25064   349977        96.952                       85.701        87.170
# 25065   349985       126.151                       29.023        95.258
# 25066   349986       164.310                        1.535       115.781
#
#        DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0         5.042              -999.000          -999.000             -999.000
# 1         2.347              -999.000          -999.000             -999.000
# 2       144.766                 4.936          1021.322               -5.834
# 3        18.079              -999.000          -999.000             -999.000
# 4        33.375                 1.370            78.189                3.443
# 5        60.490                 4.437           491.375               -4.916
# 6         5.771              -999.000          -999.000             -999.000
# 7         2.839              -999.000          -999.000             -999.000
# 8        91.566                 0.313           281.954                0.882
# 9        72.320              -999.000          -999.000             -999.000
# 10       29.691              -999.000          -999.000             -999.000
# 11        1.974              -999.000          -999.000             -999.000
# 12        3.345              -999.000          -999.000             -999.000
# 13        2.538              -999.000          -999.000             -999.000
# 14       35.277              -999.000          -999.000             -999.000
# 15       23.894              -999.000          -999.000             -999.000
# 16       23.081              -999.000          -999.000             -999.000
# 17        1.366              -999.000          -999.000             -999.000
# 18       35.115              -999.000          -999.000             -999.000
# 19      118.170              -999.000          -999.000             -999.000
# 20      154.053                 4.261           725.805               -3.512
# 21       36.406              -999.000          -999.000             -999.000
# 22       59.856              -999.000          -999.000             -999.000
# 23       49.698              -999.000          -999.000             -999.000
# 24       90.605              -999.000          -999.000             -999.000
# 25       68.274              -999.000          -999.000             -999.000
# 26        6.774              -999.000          -999.000             -999.000
# 27       28.188              -999.000          -999.000             -999.000
# 28      113.020                 1.124           103.034                0.142
# 29       46.983              -999.000          -999.000             -999.000
# ...         ...                   ...               ...                  ...
# 25037    21.482              -999.000          -999.000             -999.000
# 25038    60.184              -999.000          -999.000             -999.000
# 25039     0.843              -999.000          -999.000             -999.000
# 25040    30.420              -999.000          -999.000             -999.000
# 25041    45.621              -999.000          -999.000             -999.000
# 25042    45.930              -999.000          -999.000             -999.000
# 25043     0.413              -999.000          -999.000             -999.000
# 25044    26.142              -999.000          -999.000             -999.000
# 25045    24.200              -999.000          -999.000             -999.000
# 25046    40.256              -999.000          -999.000             -999.000
# 25047    58.653              -999.000          -999.000             -999.000
# 25048    23.661              -999.000          -999.000             -999.000
# 25049    52.799                 4.122           350.027               -3.763
# 25050    84.142                 2.128           170.719                1.163
# 25051     5.832              -999.000          -999.000             -999.000
# 25052    81.379              -999.000          -999.000             -999.000
# 25053     2.673              -999.000          -999.000             -999.000
# 25054    37.974              -999.000          -999.000             -999.000
# 25055    51.999                 2.050           127.399                1.476
# 25056     3.784              -999.000          -999.000             -999.000
# 25057   200.547                 0.058            89.467                0.181
# 25058   129.363                 0.944           200.195                5.965
# 25059    28.937              -999.000          -999.000             -999.000
# 25060   110.500              -999.000          -999.000             -999.000
# 25061   102.401                 5.058           583.129               -6.359
# 25062    47.594              -999.000          -999.000             -999.000
# 25063   139.794                 1.693           268.085                4.228
# 25064     4.503              -999.000          -999.000             -999.000
# 25065   152.684                 1.000           163.066               -0.240
# 25066     8.417              -999.000          -999.000             -999.000
#
#        DER_deltar_tau_lep  DER_pt_tot  ...    PRI_jet_num  PRI_jet_leading_pt  \
# 0                   2.116       5.042  ...              0            -999.000
# 1                   2.852       2.347  ...              0            -999.000
# 2                   1.795       0.367  ...              2             170.712
# 3                   2.346      18.079  ...              0            -999.000
# 4                   0.780      10.201  ...              2              37.734
# 5                   2.968       1.786  ...              2              86.447
# 6                   3.269       5.771  ...              0            -999.000
# 7                   3.758       2.839  ...              0            -999.000
# 8                   2.267     101.716  ...              3             148.174
# 9                   1.966      23.068  ...              1              52.929
# 10                  2.422       1.368  ...              1              30.071
# 11                  2.165       1.974  ...              0            -999.000
# 12                  2.984       3.345  ...              0            -999.000
# 13                  2.391       2.538  ...              0            -999.000
# 14                  2.498       1.548  ...              1              34.663
# 15                  3.110      23.894  ...              0            -999.000
# 16                  3.397      23.081  ...              0            -999.000
# 17                  2.998       1.366  ...              0            -999.000
# 18                  2.890       3.356  ...              1              32.329
# 19                  2.359       4.749  ...              1             121.069
# 20                  1.444      71.574  ...              3             138.456
# 21                  0.922       2.856  ...              1              36.933
# 22                  1.832      59.856  ...              0            -999.000
# 23                  3.128      33.288  ...              1              47.840
# 24                  1.648      18.342  ...              1              96.456
# 25                  2.341       2.503  ...              1              70.390
# 26                  2.334       6.774  ...              0            -999.000
# 27                  1.705       3.752  ...              1              31.633
# 28                  1.298       5.260  ...              2              89.113
# 29                  2.747       6.202  ...              1              52.754
# ...                   ...         ...  ...            ...                 ...
# 25037               3.148      21.482  ...              0            -999.000
# 25038               3.156      60.184  ...              0            -999.000
# 25039               1.594       0.843  ...              0            -999.000
# 25040               2.595       1.172  ...              1              30.065
# 25041               2.673       1.683  ...              1              45.268
# 25042               1.323      45.930  ...              0            -999.000
# 25043               3.675       0.413  ...              0            -999.000
# 25044               2.697      26.142  ...              0            -999.000
# 25045               2.552      24.200  ...              0            -999.000
# 25046               2.834       0.570  ...              1              39.868
# 25047               1.938       9.130  ...              1              49.581
# 25048               3.024      23.661  ...              0            -999.000
# 25049               2.532       1.435  ...              2              56.322
# 25050               2.038       2.818  ...              2              70.630
# 25051               2.064       5.832  ...              0            -999.000
# 25052               2.036      28.736  ...              1              58.408
# 25053               2.662       2.673  ...              0            -999.000
# 25054               2.468       1.723  ...              1              39.694
# 25055               2.585      45.170  ...              2              44.230
# 25056               1.859       3.784  ...              0            -999.000
# 25057               1.562      21.060  ...              2             183.764
# 25058               1.232      99.497  ...              3              98.894
# 25059               2.292      28.937  ...              0            -999.000
# 25060               1.883       3.785  ...              1             107.221
# 25061               2.954       7.304  ...              2              66.689
# 25062               3.084      47.594  ...              0            -999.000
# 25063               0.733      72.172  ...              3             135.927
# 25064               2.459       4.503  ...              0            -999.000
# 25065               1.504      24.642  ...              2             158.904
# 25066               3.041       8.417  ...              0            -999.000
#
#        PRI_jet_leading_eta  PRI_jet_leading_phi  PRI_jet_subleading_pt  \
# 0                 -999.000             -999.000               -999.000
# 1                 -999.000             -999.000               -999.000
# 2                   -1.961                2.220                 43.458
# 3                 -999.000             -999.000               -999.000
# 4                    2.663               -0.491                 32.666
# 5                   -2.142                0.298                 32.332
# 6                 -999.000             -999.000               -999.000
# 7                 -999.000             -999.000               -999.000
# 8                    1.109               -1.210                140.818
# 9                   -1.836                1.067               -999.000
# 10                  -0.909               -0.924               -999.000
# 11                -999.000             -999.000               -999.000
# 12                -999.000             -999.000               -999.000
# 13                -999.000             -999.000               -999.000
# 14                   1.713                0.633               -999.000
# 15                -999.000             -999.000               -999.000
# 16                -999.000             -999.000               -999.000
# 17                -999.000             -999.000               -999.000
# 18                  -0.619                0.877               -999.000
# 19                   1.697                1.707               -999.000
# 20                  -1.117                1.430                 54.651
# 21                  -3.051                0.510               -999.000
# 22                -999.000             -999.000               -999.000
# 23                  -1.748               -2.971               -999.000
# 24                   1.984                0.769               -999.000
# 25                   2.328               -0.920               -999.000
# 26                -999.000             -999.000               -999.000
# 27                   0.794                0.111               -999.000
# 28                  -1.239               -0.341                 42.907
# 29                   2.736               -2.371               -999.000
# ...                    ...                  ...                    ...
# 25037             -999.000             -999.000               -999.000
# 25038             -999.000             -999.000               -999.000
# 25039             -999.000             -999.000               -999.000
# 25040               -0.812                3.109               -999.000
# 25041               -0.660               -0.927               -999.000
# 25042             -999.000             -999.000               -999.000
# 25043             -999.000             -999.000               -999.000
# 25044             -999.000             -999.000               -999.000
# 25045             -999.000             -999.000               -999.000
# 25046               -2.631               -1.658               -999.000
# 25047               -0.813               -0.511               -999.000
# 25048             -999.000             -999.000               -999.000
# 25049               -1.365               -1.547                 34.749
# 25050                0.451               -1.827                 46.804
# 25051             -999.000             -999.000               -999.000
# 25052                0.863               -0.061               -999.000
# 25053             -999.000             -999.000               -999.000
# 25054                4.053                2.074               -999.000
# 25055               -0.564               -2.408                 40.251
# 25056             -999.000             -999.000               -999.000
# 25057                0.398                0.282                 37.559
# 25058                2.015               -2.693                 81.968
# 25059             -999.000             -999.000               -999.000
# 25060                2.432                0.759               -999.000
# 25061               -2.333               -0.913                 32.800
# 25062             -999.000             -999.000               -999.000
# 25063                1.377               -1.327                 69.015
# 25064             -999.000             -999.000               -999.000
# 25065                0.401                0.034                 34.196
# 25066             -999.000             -999.000               -999.000
#
#        PRI_jet_subleading_eta  PRI_jet_subleading_phi  PRI_jet_all_pt  \
# 0                    -999.000                -999.000           0.000
# 1                    -999.000                -999.000           0.000
# 2                       2.974                  -0.103         214.170
# 3                    -999.000                -999.000          -0.000
# 4                       1.293                  -2.358          70.400
# 5                       2.295                  -2.273         118.779
# 6                    -999.000                -999.000           0.000
# 7                    -999.000                -999.000          -0.000
# 8                       0.796                   1.344         380.547
# 9                    -999.000                -999.000          52.929
# 10                   -999.000                -999.000          30.071
# 11                   -999.000                -999.000           0.000
# 12                   -999.000                -999.000           0.000
# 13                   -999.000                -999.000           0.000
# 14                   -999.000                -999.000          34.663
# 15                   -999.000                -999.000           0.000
# 16                   -999.000                -999.000           0.000
# 17                   -999.000                -999.000          -0.000
# 18                   -999.000                -999.000          32.329
# 19                   -999.000                -999.000         121.069
# 20                      3.144                   0.688         226.618
# 21                   -999.000                -999.000          36.933
# 22                   -999.000                -999.000           0.000
# 23                   -999.000                -999.000          47.840
# 24                   -999.000                -999.000          96.456
# 25                   -999.000                -999.000          70.390
# 26                   -999.000                -999.000           0.000
# 27                   -999.000                -999.000          31.633
# 28                     -0.115                   0.790         132.019
# 29                   -999.000                -999.000          52.754
# ...                       ...                     ...             ...
# 25037                -999.000                -999.000          -0.000
# 25038                -999.000                -999.000           0.000
# 25039                -999.000                -999.000           0.000
# 25040                -999.000                -999.000          30.065
# 25041                -999.000                -999.000          45.268
# 25042                -999.000                -999.000           0.000
# 25043                -999.000                -999.000           0.000
# 25044                -999.000                -999.000          -0.000
# 25045                -999.000                -999.000          -0.000
# 25046                -999.000                -999.000          39.868
# 25047                -999.000                -999.000          49.581
# 25048                -999.000                -999.000          -0.000
# 25049                   2.757                   2.726          91.072
# 25050                   2.579                  -0.190         117.434
# 25051                -999.000                -999.000          -0.000
# 25052                -999.000                -999.000          58.408
# 25053                -999.000                -999.000           0.000
# 25054                -999.000                -999.000          39.694
# 25055                  -2.615                  -0.283          84.480
# 25056                -999.000                -999.000           0.000
# 25057                   0.455                  -0.796         221.323
# 25058                   2.960                   0.751         234.841
# 25059                -999.000                -999.000           0.000
# 25060                -999.000                -999.000         107.221
# 25061                   2.725                  -1.056          99.489
# 25062                -999.000                -999.000           0.000
# 25063                   3.070                   1.612         271.833
# 25064                -999.000                -999.000           0.000
# 25065                  -0.599                  -2.525         193.099
# 25066                -999.000                -999.000          -0.000
#
#          Weight  Label
# 0      5.121624      b
# 1      4.569368      b
# 2      0.001503      s
# 3      0.071357      b
# 4      1.916554      b
# 5      0.018636      s
# 6      2.232355      b
# 7      6.511602      b
# 8      0.001503      s
# 9      2.739652      b
# 10     2.452032      b
# 11     4.597495      b
# 12     5.444531      b
# 13     4.416257      b
# 14     0.018636      s
# 15     0.018636      s
# 16     1.681611      b
# 17     5.228417      b
# 18     2.257031      b
# 19     0.001502      s
# 20     0.064061      b
# 21     2.339817      b
# 22     0.073899      b
# 23     0.073899      b
# 24     1.454848      b
# 25     0.001503      s
# 26     4.445053      b
# 27     5.207153      b
# 28     0.018636      s
# 29     0.001503      s
# ...         ...    ...
# 25037  1.454848      b
# 25038  2.485025      b
# 25039  4.041750      b
# 25040  1.454848      b
# 25041  2.415032      b
# 25042  0.744056      b
# 25043  6.080971      b
# 25044  2.168602      b
# 25045  0.018636      s
# 25046  1.681611      b
# 25047  0.018636      s
# 25048  0.018636      s
# 25049  0.001503      s
# 25050  0.018636      s
# 25051  4.726497      b
# 25052  0.001503      s
# 25053  3.907879      b
# 25054  0.001503      s
# 25055  0.018636      s
# 25056  4.717327      b
# 25057  0.001502      s
# 25058  0.064061      b
# 25059  1.681611      b
# 25060  0.018636      s
# 25061  0.073899      b
# 25062  2.249558      b
# 25063  0.744056      b
# 25064  4.640823      b
# 25065  0.018636      s
# 25066  0.018636      s
#
# [25067 rows x 33 columns]

# %% [markdown]
# ## Explore data

# %% [markdown]
# #### Question: Print the number of rows and columns in the dataframe

# %%
shape = df.shape

print(f"Number of (rows, columns) = {shape}")
# Out:
# Number of (rows, columns) = (25067, 33)

# %% [markdown]
# #### Question: Print the top 10 rows

# %%
#look at first n rows
df.head(10)
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100018      -999.000                       85.186        68.827     5.042
# 1   100022        87.075                       38.217        67.041     2.347
# 2   100027       111.271                       27.180        70.642   144.766
# 3   100044        84.860                       33.706        67.847    18.079
# 4   100045        27.788                       68.032        23.530    33.375
# 5   100046       201.473                       23.002       104.041    60.490
# 6   100112       287.995                       72.230       229.336     5.771
# 7   100117       230.352                       85.934       164.075     2.839
# 8   100118       118.996                        2.342        72.142    91.566
# 9   100124        96.998                       30.697        78.583    72.320
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0              -999.000          -999.000             -999.000
# 1              -999.000          -999.000             -999.000
# 2                 4.936          1021.322               -5.834
# 3              -999.000          -999.000             -999.000
# 4                 1.370            78.189                3.443
# 5                 4.437           491.375               -4.916
# 6              -999.000          -999.000             -999.000
# 7              -999.000          -999.000             -999.000
# 8                 0.313           281.954                0.882
# 9              -999.000          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  ...    PRI_jet_num  PRI_jet_leading_pt  \
# 0               2.116       5.042  ...              0            -999.000
# 1               2.852       2.347  ...              0            -999.000
# 2               1.795       0.367  ...              2             170.712
# 3               2.346      18.079  ...              0            -999.000
# 4               0.780      10.201  ...              2              37.734
# 5               2.968       1.786  ...              2              86.447
# 6               3.269       5.771  ...              0            -999.000
# 7               3.758       2.839  ...              0            -999.000
# 8               2.267     101.716  ...              3             148.174
# 9               1.966      23.068  ...              1              52.929
#
#    PRI_jet_leading_eta  PRI_jet_leading_phi  PRI_jet_subleading_pt  \
# 0             -999.000             -999.000               -999.000
# 1             -999.000             -999.000               -999.000
# 2               -1.961                2.220                 43.458
# 3             -999.000             -999.000               -999.000
# 4                2.663               -0.491                 32.666
# 5               -2.142                0.298                 32.332
# 6             -999.000             -999.000               -999.000
# 7             -999.000             -999.000               -999.000
# 8                1.109               -1.210                140.818
# 9               -1.836                1.067               -999.000
#
#    PRI_jet_subleading_eta  PRI_jet_subleading_phi  PRI_jet_all_pt    Weight  \
# 0                -999.000                -999.000           0.000  5.121624
# 1                -999.000                -999.000           0.000  4.569368
# 2                   2.974                  -0.103         214.170  0.001503
# 3                -999.000                -999.000          -0.000  0.071357
# 4                   1.293                  -2.358          70.400  1.916554
# 5                   2.295                  -2.273         118.779  0.018636
# 6                -999.000                -999.000           0.000  2.232355
# 7                -999.000                -999.000          -0.000  6.511602
# 8                   0.796                   1.344         380.547  0.001503
# 9                -999.000                -999.000          52.929  2.739652
#
#    Label
# 0      b
# 1      b
# 2      s
# 3      b
# 4      b
# 5      s
# 6      b
# 7      b
# 8      s
# 9      b
#
# [10 rows x 33 columns]

# %% [markdown]
# #### Question: Print the last 10 rows

# %%
#look at last 10 rows
df.tail(10)
# Out:
#        EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 25057   349861       133.285                       14.294        59.763
# 25058   349867       105.515                       24.051        80.577
# 25059   349868        84.917                        6.755        60.607
# 25060   349876       107.016                       24.519        62.077
# 25061   349922       292.290                       76.294       101.434
# 25062   349937      -999.000                       42.555        93.236
# 25063   349966      -999.000                       83.871        17.081
# 25064   349977        96.952                       85.701        87.170
# 25065   349985       126.151                       29.023        95.258
# 25066   349986       164.310                        1.535       115.781
#
#        DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 25057   200.547                 0.058            89.467                0.181
# 25058   129.363                 0.944           200.195                5.965
# 25059    28.937              -999.000          -999.000             -999.000
# 25060   110.500              -999.000          -999.000             -999.000
# 25061   102.401                 5.058           583.129               -6.359
# 25062    47.594              -999.000          -999.000             -999.000
# 25063   139.794                 1.693           268.085                4.228
# 25064     4.503              -999.000          -999.000             -999.000
# 25065   152.684                 1.000           163.066               -0.240
# 25066     8.417              -999.000          -999.000             -999.000
#
#        DER_deltar_tau_lep  DER_pt_tot  ...    PRI_jet_num  PRI_jet_leading_pt  \
# 25057               1.562      21.060  ...              2             183.764
# 25058               1.232      99.497  ...              3              98.894
# 25059               2.292      28.937  ...              0            -999.000
# 25060               1.883       3.785  ...              1             107.221
# 25061               2.954       7.304  ...              2              66.689
# 25062               3.084      47.594  ...              0            -999.000
# 25063               0.733      72.172  ...              3             135.927
# 25064               2.459       4.503  ...              0            -999.000
# 25065               1.504      24.642  ...              2             158.904
# 25066               3.041       8.417  ...              0            -999.000
#
#        PRI_jet_leading_eta  PRI_jet_leading_phi  PRI_jet_subleading_pt  \
# 25057                0.398                0.282                 37.559
# 25058                2.015               -2.693                 81.968
# 25059             -999.000             -999.000               -999.000
# 25060                2.432                0.759               -999.000
# 25061               -2.333               -0.913                 32.800
# 25062             -999.000             -999.000               -999.000
# 25063                1.377               -1.327                 69.015
# 25064             -999.000             -999.000               -999.000
# 25065                0.401                0.034                 34.196
# 25066             -999.000             -999.000               -999.000
#
#        PRI_jet_subleading_eta  PRI_jet_subleading_phi  PRI_jet_all_pt  \
# 25057                   0.455                  -0.796         221.323
# 25058                   2.960                   0.751         234.841
# 25059                -999.000                -999.000           0.000
# 25060                -999.000                -999.000         107.221
# 25061                   2.725                  -1.056          99.489
# 25062                -999.000                -999.000           0.000
# 25063                   3.070                   1.612         271.833
# 25064                -999.000                -999.000           0.000
# 25065                  -0.599                  -2.525         193.099
# 25066                -999.000                -999.000          -0.000
#
#          Weight  Label
# 25057  0.001502      s
# 25058  0.064061      b
# 25059  1.681611      b
# 25060  0.018636      s
# 25061  0.073899      b
# 25062  2.249558      b
# 25063  0.744056      b
# 25064  4.640823      b
# 25065  0.018636      s
# 25066  0.018636      s
#
# [10 rows x 33 columns]

# %% [markdown]
# #### Question: Print the 5th row (hint: see iloc)

# %%
#look at 5th row
df.iloc[5]
# Out:
# EventId                           100046
# DER_mass_MMC                     201.473
# DER_mass_transverse_met_lep       23.002
# DER_mass_vis                     104.041
# DER_pt_h                           60.49
# DER_deltaeta_jet_jet               4.437
# DER_mass_jet_jet                 491.375
# DER_prodeta_jet_jet               -4.916
# DER_deltar_tau_lep                 2.968
# DER_pt_tot                         1.786
# DER_sum_pt                       247.731
# DER_pt_ratio_lep_tau               0.257
# DER_met_phi_centrality             1.408
# DER_lep_eta_centrality             0.688
# PRI_tau_pt                       102.618
# PRI_tau_eta                       -1.475
# PRI_tau_phi                        2.409
# PRI_lep_pt                        26.334
# PRI_lep_eta                       -1.281
# PRI_lep_phi                       -0.913
# PRI_met                           47.249
# PRI_met_phi                       -1.577
# PRI_met_sumet                    337.398
# PRI_jet_num                            2
# PRI_jet_leading_pt                86.447
# PRI_jet_leading_eta               -2.142
# PRI_jet_leading_phi                0.298
# PRI_jet_subleading_pt             32.332
# PRI_jet_subleading_eta             2.295
# PRI_jet_subleading_phi            -2.273
# PRI_jet_all_pt                   118.779
# Weight                         0.0186361
# Label                                  s
# Name: 5, dtype: object

# %% [markdown]
# #### Question: Print a statistical summary of the data (hint: describe())

# %%
#statistical properties of each column excluding categorical ones
df.describe()
# Out:
#              EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# count   25067.000000  25067.000000                 25067.000000  25067.000000
# mean   225397.098376    -51.901260                    49.850498     81.358076
# std     72529.514244    409.540625                    36.173346     41.048965
# min    100018.000000   -999.000000                     0.000000      8.345000
# 25%    162920.500000     77.224500                    19.654500     59.341500
# 50%    225469.000000    104.991000                    47.211000     73.819000
# 75%    288602.000000    130.739000                    74.123500     92.558000
# max    349986.000000    923.613000                   555.798000    732.554000
#
#            DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  25067.000000          25067.000000      25067.000000
# mean      57.967314           -707.284584       -599.017142
# std       63.029837            455.020195        660.975485
# min        0.000000           -999.000000       -999.000000
# 25%       13.741500           -999.000000       -999.000000
# 50%       38.958000           -999.000000       -999.000000
# 75%       79.637000              0.504000         84.350000
# max      584.371000              8.009000       3983.921000
#
#        DER_prodeta_jet_jet  DER_deltar_tau_lep    DER_pt_tot      ...       \
# count         25067.000000        25067.000000  25067.000000      ...
# mean           -708.248010            2.368710     18.853156      ...
# std             453.520618            0.787065     21.453734      ...
# min            -999.000000            0.277000      0.000000      ...
# 25%            -999.000000            1.800000      2.776000      ...
# 50%            -999.000000            2.482000     11.942000      ...
# 75%              -4.609500            2.963000     27.520000      ...
# max              16.219000            5.524000    319.598000      ...
#
#        PRI_met_sumet   PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count   25067.000000  25067.000000        25067.000000         25067.000000
# mean      209.779001      0.981530         -346.496788          -397.295990
# std       125.143748      0.975942          532.234503           488.944307
# min        18.534000      0.000000         -999.000000          -999.000000
# 25%       123.622000      0.000000         -999.000000          -999.000000
# 50%       180.144000      1.000000           39.356000            -1.861000
# 75%       263.875500      2.000000           75.211000             0.432500
# max      1431.990000      3.000000          652.119000             4.477000
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# count         25067.000000           25067.000000            25067.000000
# mean           -397.310975            -691.370306             -707.992995
# std             488.932196             480.130954              453.915561
# min            -999.000000            -999.000000             -999.000000
# 25%            -999.000000            -999.000000             -999.000000
# 50%              -2.059000            -999.000000             -999.000000
# 75%               0.461000              33.967000               -2.431000
# max               3.141000             494.960000                4.496000
#
#        PRI_jet_subleading_phi  PRI_jet_all_pt        Weight
# count            25067.000000    25067.000000  25067.000000
# mean              -707.994957       72.797788      1.652151
# std                453.912212       96.815491      1.873869
# min               -999.000000        0.000000      0.001502
# 25%               -999.000000        0.000000      0.018636
# 50%               -999.000000       41.108000      1.190567
# 75%                 -2.260500      109.493500      2.398923
# max                  3.139000     1114.323000      7.713018
#
# [8 rows x 32 columns]

# %% [markdown]
# #### Question: Print all the column names in the dataframe

# %%
#column names
cols = df.columns

for c in cols:
    print(c)
# Out:
# EventId
# DER_mass_MMC
# DER_mass_transverse_met_lep
# DER_mass_vis
# DER_pt_h
# DER_deltaeta_jet_jet
# DER_mass_jet_jet
# DER_prodeta_jet_jet
# DER_deltar_tau_lep
# DER_pt_tot
# DER_sum_pt
# DER_pt_ratio_lep_tau
# DER_met_phi_centrality
# DER_lep_eta_centrality
# PRI_tau_pt
# PRI_tau_eta
# PRI_tau_phi
# PRI_lep_pt
# PRI_lep_eta
# PRI_lep_phi
# PRI_met
# PRI_met_phi
# PRI_met_sumet
# PRI_jet_num
# PRI_jet_leading_pt
# PRI_jet_leading_eta
# PRI_jet_leading_phi
# PRI_jet_subleading_pt
# PRI_jet_subleading_eta
# PRI_jet_subleading_phi
# PRI_jet_all_pt
# Weight
# Label

# %% [markdown]
# ## What data is this?
#
# The Large Hadron Collider directs two beams of protons into each other at very high speeds/momenta/energies. Each collision is analogous to two ballons filled with water and glass beads inside them. When they collide, the balloons burst and the beads in one bag "collide" with beads in another bag. Most pairs of beads just "graze" each other and these are called elastic collisions (these actually result in the production of light particles e.g. pions).
#
# The interesting collisions are one where the protons hit "head-on" and result in the disintegration into internal constituents of the proton which are made of particles called quarks and gluons. Each collision is called an **event**.
#
# This data consists of an event for each row. Each event results consists of properties of particles produced during the collision. You'll see terms like **jet**, **met**, **tau**, **lep** that refer to these particles. **PRI** refers to primary i.e. values that are directly observed. **DER** refers to values *derived* from primary values.
#
# **pt**, **delta**, **phi**, **eta** refer to various angles/momenta measured during the collision.
#
# **Central Task**: the goal here is to predict the value in the column Label. We won't be predicting it but will explore the data.

# %% [markdown]
# #### Question: Look at the values in column "Label"

# %%
#look at values in one column
df['Label']
# Out:
# 0        b
# 1        b
# 2        s
# 3        b
# 4        b
# 5        s
# 6        b
# 7        b
# 8        s
# 9        b
# 10       b
# 11       b
# 12       b
# 13       b
# 14       s
# 15       s
# 16       b
# 17       b
# 18       b
# 19       s
# 20       b
# 21       b
# 22       b
# 23       b
# 24       b
# 25       s
# 26       b
# 27       b
# 28       s
# 29       s
#         ..
# 25037    b
# 25038    b
# 25039    b
# 25040    b
# 25041    b
# 25042    b
# 25043    b
# 25044    b
# 25045    s
# 25046    b
# 25047    s
# 25048    s
# 25049    s
# 25050    s
# 25051    b
# 25052    s
# 25053    b
# 25054    s
# 25055    s
# 25056    b
# 25057    s
# 25058    b
# 25059    b
# 25060    s
# 25061    b
# 25062    b
# 25063    b
# 25064    b
# 25065    s
# 25066    s
# Name: Label, Length: 25067, dtype: object

# %% [markdown]
# #### Question: Print all unique values in "Label"

# %%
#unique values in a column
df['Label'].unique()
# Out:
# array(['b', 's'], dtype=object)

# %% [markdown]
# #### Question: Find all unique values and their counts in "Label" (avoid for loops)

# %%
#unique values and counts in a column
df['Label'].value_counts()
# Out:
# b    16554
# s     8513
# Name: Label, dtype: int64

# %% [markdown]
# #### Question: Select two columns - "Label" and "PRI_jet_num"

# %%
#selecting multiple columns
df[['Label', 'PRI_jet_num']]

#equivalent to cols = ['Label', 'PRI_jet_num']
#df[cols]
# Out:
#       Label  PRI_jet_num
# 0         b            0
# 1         b            0
# 2         s            2
# 3         b            0
# 4         b            2
# 5         s            2
# 6         b            0
# 7         b            0
# 8         s            3
# 9         b            1
# 10        b            1
# 11        b            0
# 12        b            0
# 13        b            0
# 14        s            1
# 15        s            0
# 16        b            0
# 17        b            0
# 18        b            1
# 19        s            1
# 20        b            3
# 21        b            1
# 22        b            0
# 23        b            1
# 24        b            1
# 25        s            1
# 26        b            0
# 27        b            1
# 28        s            2
# 29        s            1
# ...     ...          ...
# 25037     b            0
# 25038     b            0
# 25039     b            0
# 25040     b            1
# 25041     b            1
# 25042     b            0
# 25043     b            0
# 25044     b            0
# 25045     s            0
# 25046     b            1
# 25047     s            1
# 25048     s            0
# 25049     s            2
# 25050     s            2
# 25051     b            0
# 25052     s            1
# 25053     b            0
# 25054     s            1
# 25055     s            2
# 25056     b            0
# 25057     s            2
# 25058     b            3
# 25059     b            0
# 25060     s            1
# 25061     b            2
# 25062     b            0
# 25063     b            3
# 25064     b            0
# 25065     s            2
# 25066     s            0
#
# [25067 rows x 2 columns]

# %% [markdown]
# #### Question: Find every unique combination of the two columns. In otherwise, only keep unique tuples and remove duplicate rows.

# %%
#unique values in multiple columns
df[['Label', 'PRI_jet_num']].drop_duplicates()
# Out:
#    Label  PRI_jet_num
# 0      b            0
# 2      s            2
# 4      b            2
# 8      s            3
# 9      b            1
# 14     s            1
# 15     s            0
# 20     b            3

# %% [markdown]
# #### Question: After removing duplicates, sort result by "Label" and "PRI_jet_num"

# %%
#sorting by a column
df[['Label', 'PRI_jet_num']].drop_duplicates().sort_values(by=['Label', 'PRI_jet_num'])
# Out:
#    Label  PRI_jet_num
# 0      b            0
# 9      b            1
# 4      b            2
# 20     b            3
# 15     s            0
# 14     s            1
# 2      s            2
# 8      s            3

# %% [markdown]
# #### Question: Sorting a large dataframe will create another copy. Is there a way to do this in a more memory-efficient manner (hint: see arguments to the sorting function)

# %%
#for memory efficiency, do in-place operations

df2 = df[['Label', 'PRI_jet_num']].drop_duplicates()

df2.sort_values(by=['Label', 'PRI_jet_num'], inplace=True, ascending=False)

df2
# Out:
#    Label  PRI_jet_num
# 8      s            3
# 2      s            2
# 14     s            1
# 15     s            0
# 20     b            3
# 4      b            2
# 9      b            1
# 0      b            0

# %% [markdown]
# ### Filtering data

# %% [markdown]
# #### Question: Select all rows where "Label" = "s". How many rows do you get?

# %%
#often want to filter rows

df['Label']=='s' #returns boolean array -> use to index dataframe
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
# 5         True
# 6        False
# 7        False
# 8         True
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14        True
# 15        True
# 16       False
# 17       False
# 18       False
# 19        True
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25        True
# 26       False
# 27       False
# 28        True
# 29        True
#          ...
# 25037    False
# 25038    False
# 25039    False
# 25040    False
# 25041    False
# 25042    False
# 25043    False
# 25044    False
# 25045     True
# 25046    False
# 25047     True
# 25048     True
# 25049     True
# 25050     True
# 25051    False
# 25052     True
# 25053    False
# 25054     True
# 25055     True
# 25056    False
# 25057     True
# 25058    False
# 25059    False
# 25060     True
# 25061    False
# 25062    False
# 25063    False
# 25064    False
# 25065     True
# 25066     True
# Name: Label, Length: 25067, dtype: bool

# %%
df[df['Label']=='s'].shape
# Out:
# (8513, 33)

# %%
#composite statements

df[(df['DER_mass_MMC'] > 120) & (df['Label']=='b')].shape
# Out:
# (4350, 33)

# %% [markdown]
# ### Useful concepts and operations
#
# ### Index

# %% [markdown]
# #### Question: Print out the index values in the dataframe

# %%
df.head() #indexed by integers (left-most entry)
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100018      -999.000                       85.186        68.827     5.042
# 1   100022        87.075                       38.217        67.041     2.347
# 2   100027       111.271                       27.180        70.642   144.766
# 3   100044        84.860                       33.706        67.847    18.079
# 4   100045        27.788                       68.032        23.530    33.375
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0              -999.000          -999.000             -999.000
# 1              -999.000          -999.000             -999.000
# 2                 4.936          1021.322               -5.834
# 3              -999.000          -999.000             -999.000
# 4                 1.370            78.189                3.443
#
#    DER_deltar_tau_lep  DER_pt_tot  ...    PRI_jet_num  PRI_jet_leading_pt  \
# 0               2.116       5.042  ...              0            -999.000
# 1               2.852       2.347  ...              0            -999.000
# 2               1.795       0.367  ...              2             170.712
# 3               2.346      18.079  ...              0            -999.000
# 4               0.780      10.201  ...              2              37.734
#
#    PRI_jet_leading_eta  PRI_jet_leading_phi  PRI_jet_subleading_pt  \
# 0             -999.000             -999.000               -999.000
# 1             -999.000             -999.000               -999.000
# 2               -1.961                2.220                 43.458
# 3             -999.000             -999.000               -999.000
# 4                2.663               -0.491                 32.666
#
#    PRI_jet_subleading_eta  PRI_jet_subleading_phi  PRI_jet_all_pt    Weight  \
# 0                -999.000                -999.000            0.00  5.121624
# 1                -999.000                -999.000            0.00  4.569368
# 2                   2.974                  -0.103          214.17  0.001503
# 3                -999.000                -999.000           -0.00  0.071357
# 4                   1.293                  -2.358           70.40  1.916554
#
#    Label
# 0      b
# 1      b
# 2      s
# 3      b
# 4      b
#
# [5 rows x 33 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=25067, step=1)

# %% [markdown]
# #### Question: Set "EventId" as the index

# %%
#can set another column as index

df2 = df.set_index('EventId')

# %%
df2.head()
# Out:
#          DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# EventId
# 100018       -999.000                       85.186        68.827     5.042
# 100022         87.075                       38.217        67.041     2.347
# 100027        111.271                       27.180        70.642   144.766
# 100044         84.860                       33.706        67.847    18.079
# 100045         27.788                       68.032        23.530    33.375
#
#          DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# EventId
# 100018               -999.000          -999.000             -999.000
# 100022               -999.000          -999.000             -999.000
# 100027                  4.936          1021.322               -5.834
# 100044               -999.000          -999.000             -999.000
# 100045                  1.370            78.189                3.443
#
#          DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  ...    PRI_jet_num  \
# EventId                                              ...
# 100018                2.116       5.042      71.443  ...              0
# 100022                2.852       2.347      65.281  ...              0
# 100027                1.795       0.367     309.992  ...              2
# 100044                2.346      18.079      73.320  ...              0
# 100045                0.780      10.201     132.965  ...              2
#
#          PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# EventId
# 100018             -999.000             -999.000             -999.000
# 100022             -999.000             -999.000             -999.000
# 100027              170.712               -1.961                2.220
# 100044             -999.000             -999.000             -999.000
# 100045               37.734                2.663               -0.491
#
#          PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# EventId
# 100018                -999.000                -999.000
# 100022                -999.000                -999.000
# 100027                  43.458                   2.974
# 100044                -999.000                -999.000
# 100045                  32.666                   1.293
#
#          PRI_jet_subleading_phi  PRI_jet_all_pt    Weight  Label
# EventId
# 100018                 -999.000            0.00  5.121624      b
# 100022                 -999.000            0.00  4.569368      b
# 100027                   -0.103          214.17  0.001503      s
# 100044                 -999.000           -0.00  0.071357      b
# 100045                   -2.358           70.40  1.916554      b
#
# [5 rows x 32 columns]

# %%
df2.index
# Out:
# Int64Index([100018, 100022, 100027, 100044, 100045, 100046, 100112, 100117,
#             100118, 100124,
#             ...
#             349861, 349867, 349868, 349876, 349922, 349937, 349966, 349977,
#             349985, 349986],
#            dtype='int64', name='EventId', length=25067)

# %% [markdown]
# #### Question: Set both "EventId" and "Label" as indices (tuple-valued index)

# %%
#multiple columns as index

df2 = df.set_index(['EventId', 'Label'])

# %%
df2.index[0]
# Out:
# (100018, 'b')

# %% [markdown]
# ### Group by

# %% [markdown]
# #### Question: Group the data by "Label" and get the number of rows in each group ("s" and "b")

# %%
#number of rows
df.groupby(by=['Label']).count()
# Out:
#        EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# Label
# b        16554         16554                        16554         16554
# s         8513          8513                         8513          8513
#
#        DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# Label
# b         16554                 16554             16554                16554
# s          8513                  8513              8513                 8513
#
#        DER_deltar_tau_lep  DER_pt_tot   ...    PRI_met_sumet  PRI_jet_num  \
# Label                                   ...
# b                   16554       16554   ...            16554        16554
# s                    8513        8513   ...             8513         8513
#
#        PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# Label
# b                   16554                16554                16554
# s                    8513                 8513                 8513
#
#        PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# Label
# b                      16554                   16554                   16554
# s                       8513                    8513                    8513
#
#        PRI_jet_all_pt  Weight
# Label
# b               16554   16554
# s                8513    8513
#
# [2 rows x 32 columns]

# %% [markdown]
# #### Question: Group the data by "Label" and get the mean value in each group for each column

# %%
#mean or average
df.groupby(by=['Label']).mean()
# Out:
#              EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# Label
# b      225534.293283   -120.625799                    58.764847     81.799202
# s      225130.315283     81.737412                    32.516053     80.500283
#
#         DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# Label
# b      49.478986           -753.280941       -691.141168          -753.719939
# s      74.473339           -617.842119       -419.876872          -619.825327
#
#        DER_deltar_tau_lep  DER_pt_tot    ...     PRI_met_sumet  PRI_jet_num  \
# Label                                    ...
# b                2.356830   19.178065    ...        198.486687     0.890782
# s                2.391813   18.221352    ...        231.737532     1.157994
#
#        PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# Label
# b             -404.661848          -448.082697          -448.098932
# s             -233.391607          -298.538425          -298.550980
#
#        PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# Label
# b                -739.568709             -753.751196             -753.750502
# s                -597.645843             -619.013640             -619.020766
#
#        PRI_jet_all_pt    Weight
# Label
# b           63.596448  2.497627
# s           90.690305  0.008075
#
# [2 rows x 32 columns]

# %% [markdown]
# #### Question: Group the data by "Label" and get the standard deviation value in each group for each column

# %%
#standard deviation
df.groupby(by=['Label']).std()
# Out:
#             EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# Label
# b      72613.208338    465.630886                    35.331625     48.001977
# s      72370.005222    212.686517                    31.155208     21.909304
#
#         DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# Label
# b      55.160213            430.781329        551.822444           430.013355
# s      73.276035            486.524291        803.601839           483.998021
#
#        DER_deltar_tau_lep  DER_pt_tot    ...     PRI_met_sumet  PRI_jet_num  \
# Label                                    ...
# b                0.832501   21.417863    ...        123.862928     0.981633
# s                0.689662   21.510529    ...        124.710826     0.940081
#
#        PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# Label
# b              537.651715           496.863884           496.849611
# s              502.655071           457.320336           457.311570
#
#        PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# Label
# b                 455.127914              429.957289              429.958510
# s                 512.566385              485.029542              485.019642
#
#        PRI_jet_all_pt    Weight
# Label
# b           94.969328  1.792269
# s           97.867496  0.008230
#
# [2 rows x 32 columns]

# %% [markdown]
# #### Question: Group the data by "Label" and
# 1. get the percentage of rows in each group for the column "DER_mass_MMC"
# 2.the sum of the squares of the values in each group for the column "DER_pt_h"

# %%
#custom function applied to a column
#function should return a single numeric value
df.groupby(by=['Label']).agg({
                              'DER_mass_MMC': lambda x: len(x)/float(df.shape[0]), 
                              'DER_pt_h': lambda x: np.sum(x**2)
                             })
# Out:
#        DER_mass_MMC      DER_pt_h
# Label
# b           0.66039  9.089198e+07
# s           0.33961  9.291961e+07

# %% [markdown]
# #### Question: Group the data by "Label" and loop over each group (name of group and data associated with it)

# %%
#groups
groups = df.groupby('Label')

for name, group in groups:
    print(name, group.shape)
    #add logic to parse group data
# Out:
# b (16554, 33)
# s (8513, 33)

# %% [markdown]
# ### Column-wise or row-wise operations - apply

# %% [markdown]
# #### Question: Choose the first 10 columns and find the mean across each column

# %%
df[df.columns[0:10]] #first 10 columns

df[df.columns[0:10]].apply(np.mean, axis=0) #axis=0 -> column-wise operations
# Out:
# EventId                        225397.098376
# DER_mass_MMC                      -51.901260
# DER_mass_transverse_met_lep        49.850498
# DER_mass_vis                       81.358076
# DER_pt_h                           57.967314
# DER_deltaeta_jet_jet             -707.284584
# DER_mass_jet_jet                 -599.017142
# DER_prodeta_jet_jet              -708.248010
# DER_deltar_tau_lep                  2.368710
# DER_pt_tot                         18.853156
# dtype: float64

# %% [markdown]
# #### Question: Choose the first 10 columns and find the mean across each row

# %%
df[df.columns[0:10]].head(10).apply(np.mean, axis=1) #axis=1 -> row-wise operations
# Out:
# 0     9618.8213
# 1     9722.4879
# 2    10140.3445
# 3     9727.1917
# 4    10029.1708
# 5    10093.0656
# 6     9771.9372
# 7     9760.9797
# 8    10079.0178
# 9     9743.0632
# dtype: float64

# %% [markdown]
# #### Question: Choose the first 10 rows and compute the ratio of the columns "PRI_jet_all_pt" to "PRI_jet_num" (average jet pt)

# %%
#can use lambda functions

#total jet pt / number of jets -> average jet pt per event
df.head(10).apply(lambda x: x['PRI_jet_all_pt'] / float(x['PRI_jet_num']) if x['PRI_jet_num']>0 else 0, axis=1)
# Out:
# 0      0.0000
# 1      0.0000
# 2    107.0850
# 3      0.0000
# 4     35.2000
# 5     59.3895
# 6      0.0000
# 7      0.0000
# 8    126.8490
# 9     52.9290
# dtype: float64

# %% [markdown]
# ### Drop columns and rows

# %% [markdown]
# #### Question: Drop/remove the column "PRI_jet_all_pt" from the dataframe. Check the number of columns before/after dropping it. Is there a memory efficient way of doing this?

# %%
df2 = df.drop('PRI_jet_all_pt', axis=1) #axis=1 -> drop column

# %%
print(df.shape)
print(df2.shape)
# Out:
# (25067, 33)
# (25067, 32)

# %%
#also in-place memory-efficient version

#df.drop('PRI_jet_all_pt', inplace=True)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=25067, step=1)

# %% [markdown]
# #### Question: Use the same function to drop the first 10000 rows

# %%
df2 = df.drop(np.arange(0, 10000), axis=0) #axis=0 -> drop rows

print(df2.shape)

#seldom useful -> rows are usually dropped through filtering
#useful to drop columns though
# Out:
# (15067, 33)

# %% [markdown]
# ### Dealing with nulls

# %% [markdown]
# #### Question: Check if the data has any nulls in any column

# %%
df.isnull().sum(axis=0)
# Out:
# EventId                        0
# DER_mass_MMC                   0
# DER_mass_transverse_met_lep    0
# DER_mass_vis                   0
# DER_pt_h                       0
# DER_deltaeta_jet_jet           0
# DER_mass_jet_jet               0
# DER_prodeta_jet_jet            0
# DER_deltar_tau_lep             0
# DER_pt_tot                     0
# DER_sum_pt                     0
# DER_pt_ratio_lep_tau           0
# DER_met_phi_centrality         0
# DER_lep_eta_centrality         0
# PRI_tau_pt                     0
# PRI_tau_eta                    0
# PRI_tau_phi                    0
# PRI_lep_pt                     0
# PRI_lep_eta                    0
# PRI_lep_phi                    0
# PRI_met                        0
# PRI_met_phi                    0
# PRI_met_sumet                  0
# PRI_jet_num                    0
# PRI_jet_leading_pt             0
# PRI_jet_leading_eta            0
# PRI_jet_leading_phi            0
# PRI_jet_subleading_pt          0
# PRI_jet_subleading_eta         0
# PRI_jet_subleading_phi         0
# PRI_jet_all_pt                 0
# Weight                         0
# Label                          0
# dtype: int64

# %% [markdown]
# #### Question: Drop all rows with >=1 nulls and check how many rows are left

# %%
#will drop any row with 1 or more nulls in the columns
df.dropna().shape #or df.dropna(inplace=True) for memory-efficiency
# Out:
# (25067, 33)

# %% [markdown]
# #### Question: Replace all nulls with a fixed value, say 0

# %%
#fill nulls
df.fillna(0).shape #df.fillna(inplace=True) for memory-efficiency
# Out:
# (25067, 33)

# %% [markdown]
# #### Question: Replace all nulls in a single column ("PRI_jet_subleading_pt") with a fixed value

# %%
#for filling nulls in one column
df['PRI_jet_num'].fillna(-1).head()
# Out:
# 0    0
# 1    0
# 2    2
# 3    0
# 4    2
# Name: PRI_jet_num, dtype: int64

# %% [markdown]
# ### Replacing values

# %% [markdown]
# #### Question: Look at the unique values and their counts in the column "PRI_jet_subleading_pt"

# %%
df['PRI_jet_subleading_pt'].value_counts() #most are -999 (nulls)
# Out:
# -999.000    17765
#  40.816         4
#  50.173         4
#  35.387         4
#  36.362         3
#  40.814         3
#  36.369         3
#  39.535         3
#  38.077         3
#  30.853         3
#  42.167         3
#  42.963         3
#  32.041         3
#  36.592         3
#  41.155         3
#  37.711         3
#  42.496         3
#  32.596         3
#  68.695         3
#  31.830         3
#  32.529         3
#  34.067         3
#  30.096         3
#  34.021         3
#  32.177         2
#  43.963         2
#  32.412         2
#  31.311         2
#  34.519         2
#  31.776         2
#             ...
#  49.712         1
#  47.126         1
#  55.762         1
#  59.329         1
#  53.817         1
#  60.233         1
#  40.174         1
#  80.152         1
#  38.471         1
#  41.527         1
#  30.372         1
#  30.128         1
#  47.623         1
#  33.803         1
#  35.993         1
#  128.245        1
#  50.073         1
#  39.923         1
#  30.798         1
#  36.366         1
#  72.006         1
#  42.197         1
#  36.053         1
#  36.207         1
#  61.963         1
#  45.787         1
#  36.261         1
#  44.016         1
#  97.359         1
#  30.592         1
# Name: PRI_jet_subleading_pt, Length: 6816, dtype: int64

# %% [markdown]
# #### Question: "PRI_jet_subleading_pt" has empty values but they are not NaNs but are instead populated by -999. Replace all these values with np.nan

# %%
df['PRI_jet_subleading_pt'].replace(to_replace=-999, value=np.nan) #replace "to_replace" by "value"

#replace the column
df['PRI_jet_subleading_pt'] = df['PRI_jet_subleading_pt'].replace(to_replace=-999, value=np.nan) #replace "to_replace" by "value"

# %%
df.isnull().sum(axis=0)
# Out:
# EventId                            0
# DER_mass_MMC                       0
# DER_mass_transverse_met_lep        0
# DER_mass_vis                       0
# DER_pt_h                           0
# DER_deltaeta_jet_jet               0
# DER_mass_jet_jet                   0
# DER_prodeta_jet_jet                0
# DER_deltar_tau_lep                 0
# DER_pt_tot                         0
# DER_sum_pt                         0
# DER_pt_ratio_lep_tau               0
# DER_met_phi_centrality             0
# DER_lep_eta_centrality             0
# PRI_tau_pt                         0
# PRI_tau_eta                        0
# PRI_tau_phi                        0
# PRI_lep_pt                         0
# PRI_lep_eta                        0
# PRI_lep_phi                        0
# PRI_met                            0
# PRI_met_phi                        0
# PRI_met_sumet                      0
# PRI_jet_num                        0
# PRI_jet_leading_pt                 0
# PRI_jet_leading_eta                0
# PRI_jet_leading_phi                0
# PRI_jet_subleading_pt          17765
# PRI_jet_subleading_eta             0
# PRI_jet_subleading_phi             0
# PRI_jet_all_pt                     0
# Weight                             0
# Label                              0
# dtype: int64

# %%
df.dropna().shape
# Out:
# (7302, 33)

# %%
df.fillna(0).dropna().shape
# Out:
# (25067, 33)

# %% [markdown]
# ### Pivot Tables

# %% [markdown]
# #### Question: Create a pivot table to get the average value in each group specified by "Label" and "PRI_jet_num" (can be done with groupbys too but we want a pivot table)

# %%
pd.pivot_table(df, index='Label', columns='PRI_jet_num', values='PRI_met', aggfunc='mean')
# Out:
# PRI_jet_num          0          1          2          3
# Label
# b            34.457258  40.285103  51.345472  63.074694
# s            23.125440  41.107180  55.795808  74.128886

# %% [markdown]
# #### Question: Create a pivot table to get the standard deviation in each group specified by "Label" and "PRI_jet_num" (can be done with groupbys too but we want a pivot table)

# %%
pd.pivot_table(df, index='Label', columns='PRI_jet_num', values='PRI_met', aggfunc='std')
# Out:
# PRI_jet_num          0          1          2          3
# Label
# b            16.766071  26.928465  36.861710  47.778423
# s            20.396983  32.093888  40.766551  56.289727

# %% [markdown]
# ### One-hot encoding
#
# Machine learning algorithms are statistical in nature and cannot handle string-valued columns without pre-processing. There are multiple ways to convert string columns to numerical ones but probably the most common way is one-hot encoding. An example will make this clear:
#
# Column A
#
# Apple
#
# Mango
#
# Apple
#
# Apple
#
# Strawberry
#
# One-hot encoded value will count the number of unique values in column (3 in this case) and map each one to:
#
# Apple -> (1,0,0)
#
# Mango -> (0,1,0)
#
# Strawberry -> (0,0,1)

# %% [markdown]
# #### Question: Look at the first 10 values of "Label"

# %%
df['Label'].head(10)
# Out:
# 0    b
# 1    b
# 2    s
# 3    b
# 4    b
# 5    s
# 6    b
# 7    b
# 8    s
# 9    b
# Name: Label, dtype: object

# %% [markdown]
# #### Question: Convert "Label" to one-hot encoded values (hint: see pd.get_dummies)

# %%
pd.get_dummies(df['Label'].head(10), prefix='Label')
# Out:
#    Label_b  Label_s
# 0        1        0
# 1        1        0
# 2        0        1
# 3        1        0
# 4        1        0
# 5        0        1
# 6        1        0
# 7        1        0
# 8        0        1
# 9        1        0

# %% [markdown]
# ### Plotting
#
# While exploring data, plotting and visualization is a key component. One can treat pandas columns as numpy arrays and use matplotlib or use python's wrappers for visualization.

# %%
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# #### Question: Make a histogram for "PRI_jet_num"

# %%
df['PRI_jet_num'].hist()

# %% [markdown]
# #### Question: Plot "PRI_jet_all_pt"

# %%
df['PRI_jet_all_pt'].plot() #not very useful

# %% [markdown]
# #### Question: Make a histogram for "PRI_jet_all_pt"

# %%
df['PRI_jet_all_pt'].hist()

# %% [markdown]
# #### Question: (Scatter) Plot PRI_let_pt vs PRI_jet_all_pt

# %%
df.plot(x='PRI_jet_all_pt', y='PRI_lep_pt', kind='scatter')

# %% [markdown]
# #### Question: Make a density plot of PRI_jet_all_pt

# %%
df['PRI_jet_all_pt'].plot(kind='density')

# %% [markdown]
# ### Concatenation

# %% [markdown]
# #### Question: Split the data into two pieces with part 1: first 10 columns, part 2: columns 10-20

# %%
df1 = df[df.columns[0:10]]
df2 = df[df.columns[10:]]

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (25067, 10)
# (25067, 23)

# %%
df1.iloc[0]
# Out:
# EventId                        100018.000
# DER_mass_MMC                     -999.000
# DER_mass_transverse_met_lep        85.186
# DER_mass_vis                       68.827
# DER_pt_h                            5.042
# DER_deltaeta_jet_jet             -999.000
# DER_mass_jet_jet                 -999.000
# DER_prodeta_jet_jet              -999.000
# DER_deltar_tau_lep                  2.116
# DER_pt_tot                          5.042
# Name: 0, dtype: float64

# %%
df2.iloc[0]
# Out:
# DER_sum_pt                 71.443
# DER_pt_ratio_lep_tau        1.558
# DER_met_phi_centrality     -1.351
# DER_lep_eta_centrality       -999
# PRI_tau_pt                 27.931
# PRI_tau_eta                 1.175
# PRI_tau_phi                 2.356
# PRI_lep_pt                 43.512
# PRI_lep_eta                 2.332
# PRI_lep_phi                 0.584
# PRI_met                    44.698
# PRI_met_phi                -2.033
# PRI_met_sumet             151.816
# PRI_jet_num                     0
# PRI_jet_leading_pt           -999
# PRI_jet_leading_eta          -999
# PRI_jet_leading_phi          -999
# PRI_jet_subleading_pt         NaN
# PRI_jet_subleading_eta       -999
# PRI_jet_subleading_phi       -999
# PRI_jet_all_pt                  0
# Weight                    5.12162
# Label                           b
# Name: 0, dtype: object

# %% [markdown]
# #### Question: concat the two pieces together to form the original dataset again

# %%
df_alt = pd.concat([df1, df2], axis=1) #add more columns
print(df_alt.shape)
# Out:
# (25067, 33)

# %%
df.head(10).index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
pd.concat([df.head(10).tail(5), df.head(5)], axis=0).index #add more rows
# Out:
# Int64Index([5, 6, 7, 8, 9, 0, 1, 2, 3, 4], dtype='int64')

# %% [markdown]
# ### Joins

# %% [markdown]
# #### Question: Suppose we are provided the dataset below. We want to add relevant columns to our dataframe i.e. join the two dataset. How would you do that (hint: merge)?

# %%
df_new = pd.DataFrame({'Label': ['s', 'b'], 'Title': ['Supersymmetry', 'StandardModel'], 'LSPMass': [1000, np.nan]})

# %%
df_new
# Out:
#   Label          Title  LSPMass
# 0     s  Supersymmetry   1000.0
# 1     b  StandardModel      NaN

# %%
df2 = pd.merge(df, df_new, on=['Label'], how='left')

# %%
df2.iloc[10]
# Out:
# EventId                               100132
# DER_mass_MMC                            -999
# DER_mass_transverse_met_lep           69.946
# DER_mass_vis                         110.636
# DER_pt_h                              29.691
# DER_deltaeta_jet_jet                    -999
# DER_mass_jet_jet                        -999
# DER_prodeta_jet_jet                     -999
# DER_deltar_tau_lep                     2.422
# DER_pt_tot                             1.368
# DER_sum_pt                           107.946
# DER_pt_ratio_lep_tau                   0.779
# DER_met_phi_centrality                -1.286
# DER_lep_eta_centrality                  -999
# PRI_tau_pt                            43.767
# PRI_tau_eta                            0.854
# PRI_tau_phi                            1.609
# PRI_lep_pt                            34.109
# PRI_lep_eta                           -1.369
# PRI_lep_phi                            2.572
# PRI_met                               40.887
# PRI_met_phi                           -1.286
# PRI_met_sumet                        120.657
# PRI_jet_num                                1
# PRI_jet_leading_pt                    30.071
# PRI_jet_leading_eta                   -0.909
# PRI_jet_leading_phi                   -0.924
# PRI_jet_subleading_pt                    NaN
# PRI_jet_subleading_eta                  -999
# PRI_jet_subleading_phi                  -999
# PRI_jet_all_pt                        30.071
# Weight                               2.45203
# Label                                      b
# Title                          StandardModel
# LSPMass                                  NaN
# Name: 10, dtype: object

# %%
df2[['Label', 'Title', 'LSPMass']].drop_duplicates()
# Out:
#   Label          Title  LSPMass
# 0     b  StandardModel      NaN
# 2     s  Supersymmetry   1000.0

# %%
#Signature of pd.merge
#left_on: what columns in the first argument df to join on
#right_on: what columns in the second argument df to join on
#how: 'left', 'right', 'inner', 'outer'
